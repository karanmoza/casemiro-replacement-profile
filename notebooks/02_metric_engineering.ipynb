# %% [markdown]
# # 02 Metric Engineering
#
# Create per-90 metrics, touch-adjusted possession-risk rates, inverse-risk columns, and age/minutes proxy scores.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.load_fbref import load_fbref_player_stats
from src.metrics import prepare_metrics

raw = load_fbref_player_stats()
metrics = prepare_metrics(raw)
metrics[['player', 'tackles_interceptions_per90', 'turnover_rate', 'age_score', 'minutes_score']].head(10)
