# %% [markdown]
# # 01 Data Collection
#
# Load FBref-style/public aggregate data and document how StatsBomb open data demonstrates the event-data logic behind the role profile. The project includes a sample fallback so the workflow is reproducible offline.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.load_fbref import load_fbref_player_stats, write_sample_dataset
from src.load_statsbomb import load_statsbomb_events, engineer_event_control_metrics

write_sample_dataset()
fbref = load_fbref_player_stats()
events = load_statsbomb_events()
event_metrics = engineer_event_control_metrics(events)

fbref.head(), event_metrics.head()
